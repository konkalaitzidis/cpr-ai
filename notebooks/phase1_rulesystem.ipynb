# %%
import sys
import os

# Ensure Colab or VS Code can find the src/ directory
sys.path.append(os.path.abspath('../src'))

from recommend import recommend_next_step

# Try out some test cases
print(recommend_next_step('Chest pain', 'Senior'))   # Chest X-ray
print(recommend_next_step('Fever', 'Child'))         # Throat swab
print(recommend_next_step('Headache', 'Adult'))      # Neurology consult
# Out:
# Chest X-ray
# Throat swab
# Neurology consult
